# %% [markdown]
# <a href="https://colab.research.google.com/github/netsecer-mahesh/Security/blob/main/Day01_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Firewall Inventory Simulation
#
# This section stores basic firewall information
# that can later be retrieved using Palo Alto APIs.

# %%
firewall_name = "PA-LAB-01"
disabled_rules = 20

print("Checking firewall:", firewall_name)

if disabled_rules > 10:
    print("ALERT: Too many disabled rules")
else:
    print("STATUS: Firewall policy looks good")
# Out:
# Checking firewall: PA-LAB-01
# ALERT: Too many disabled rules
