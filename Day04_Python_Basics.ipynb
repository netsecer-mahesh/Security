# %% [markdown]
# <a href="https://colab.research.google.com/github/netsecer-mahesh/Security/blob/main/Day04_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
firewall_A = {
    "hostname": "PA-CLN-3410-A",
    "model": "PA-3410",
    "interfaces": [
        "ethernet1/1",
        "ethernet1/2"
    ],
    "security_rules": [
        "Allow-Web",
        "Allow-DNS",
        "Block-Telnet",
        "Block-SSH"
    ]
}
firewall_B = {
    "hostname": "PA-CLN-3410-B",
    "model": "PA-3410",
    "interfaces": [
        "ethernet2/1",
        "ethernet2/2",
        "ethernet2/3"
    ],
    "security_rules": [
        "Allow-Web",
        "Allow-DNS",
        "Block-Telnet"
    ]
}
firewall_D = {
    "hostname": "PA-CLN-3410-D",
    "model": "PA-3410",
    "interfaces": [
        "ethernet1/1",
        "ethernet1/2"
    ],
    "security_rules": [
        "Allow-Web",
        "Allow-DNS"
    ]
}
firewall_C = {
    "hostname": "PA-CLN-3410-C",
    "model": "PA-3410",
    "interfaces": [
        "ethernet1/1",
        "ethernet1/2"
    ],
    "security_rules": [
        "Allow-Web",
        "Allow-DNS",
        "Block-Telnet",
        "Block-SSH"
    ]
}
firewall_E = {
    "hostname": "PA-CLN-3410-E",
    "model": "PA-3410",
    "interfaces": [
        "ethernet1/1",
        "ethernet1/2"
    ],
    "security_rules": [
        "Allow-Web",
        "Allow-DNS",
        "Block-Telnet",
        "Block-SSH"
    ]
}

Firewalls = [
    firewall_A,
    firewall_B,
    firewall_C,
    firewall_D,
    firewall_E
]




for firewall in Firewalls:
      if "Block-telnet" in (firewall["security_rules"]) :
         print("hostname:", firewall["hostname"])
         print("model:", firewall["model"])
         print("firewall", firewall["hostname"], "ssh blocked")
         print("*" * 40)
      else:
        print("firewall", firewall["hostname"], "ssh is not blocked")
        print("*" * 40)
# Out:
# firewall PA-CLN-3410-A ssh is not blocked
# ****************************************
# firewall PA-CLN-3410-B ssh is not blocked
# ****************************************
# firewall PA-CLN-3410-C ssh is not blocked
# ****************************************
# firewall PA-CLN-3410-D ssh is not blocked
# ****************************************
# firewall PA-CLN-3410-E ssh is not blocked
# ****************************************
