# %% [markdown]
# <a href="https://colab.research.google.com/github/netsecer-mahesh/Security/blob/main/Day02_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
firewall = {
    "hostname": "PA-LAB-01",
    "model": "PA-3410",
    "interfaces": [
        "ethernet1/1",
        "ethernet1/2"
    ],
    "security_rules": [
        "Allow-Web",
        "Allow-DNS",
        "Block-Telnet"
    ]
}
print(firewall["security_rules"][2])
# Out:
# Block-Telnet
