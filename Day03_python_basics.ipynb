# %% [markdown]
# <a href="https://colab.research.google.com/github/netsecer-mahesh/Security/blob/main/Day03_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
firewall_A = {
    "hostname": "PA-CLN-3410-A",
    "model": "PA-3410",
    "interfaces": [
        "ethernet1/1",
        "ethernet1/2"
    ],
    "security_rules": [
        "Allow-Web",
        "Allow-DNS",
        "Block-Telnet",
        "Block-SSH"
    ]
}
firewall_B = {
    "hostname": "PA-CLN-3410-B",
    "model": "PA-3410",
    "interfaces": [
        "ethernet2/1",
        "ethernet2/2",
        "ethernet2/3"
    ],
    "security_rules": [
        "Allow-Web",
        "Allow-DNS",
        "Block-SSH",
        "Block-Telnet"
    ]
}
firewall_D = {
    "hostname": "PA-CLN-3410-D",
    "model": "PA-3410",
    "interfaces": [
        "ethernet1/1",
        "ethernet1/2"
    ],
    "security_rules": [
        "Allow-Web",
        "Allow-DNS"
    ]
}
firewall_C = {
    "hostname": "PA-CLN-3410-C",
    "model": "PA-3410",
    "interfaces": [
        "ethernet1/1",
        "ethernet1/2"
    ],
    "security_rules": [
        "Allow-Web",
        "Allow-DNS",
        "Block-Telnet",
        "Block-SSH"
    ]
}
firewall_E = {
    "hostname": "PA-CLN-3410-C",
    "model": "PA-3410",
    "interfaces": [
        "ethernet1/1",
        "ethernet1/2"
    ],
    "security_rules": [
        "Allow-Web",
        "Allow-DNS",
        "Block-Telnet",
        "Block-SSH"
    ]
}

Firewalls = [
    firewall_A,
    firewall_B,
    firewall_C,
    firewall_D,
    firewall_E
]

for firewall in Firewalls:
   if len(firewall["security_rules"]) > 0:
    print("Policy review required")
    print("Hostname:", firewall["hostname"])
   else:
    print("Policy looks clean","Hostname:", firewall["hostname"])
    print("______________________________________")

hostnames = []
for firewall in Firewalls:
    if firewall["hostname"] in hostnames:
        print("Duplicate firewall found:", firewall["hostname"])
    else:
        hostnames.append(firewall["hostname"])
# Out:
# Policy review required
# Hostname: PA-CLN-3410-A
# Policy review required
# Hostname: PA-CLN-3410-B
# Policy review required
# Hostname: PA-CLN-3410-C
# Policy looks clean Hostname: PA-CLN-3410-D
# ______________________________________
# Policy review required
# Hostname: PA-CLN-3410-C
# Duplicate firewall found: PA-CLN-3410-C
